# %% [markdown]
# <a href="https://colab.research.google.com/github/sabumjung/Machine-Learning-Algorithm/blob/master/ch07_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 커널 SVM

# %%
import numpy as np
import multiprocessing

from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
# For reproducibility
np.random.seed(1000)

# %%
# Set a local folder here
olivetti_home = ''

# %%
# Load dataset

faces = fetch_olivetti_faces(data_home=olivetti_home)
# Define a param grid
param_grid = [
    {
        'kernel': ['rbf', 'poly'],
        'C': [0.1, 0.5, 1.0, 1.5],
        'degree': [2, 3, 4, 5],
        'gamma': [0.001, 0.01, 0.1, 0.5]
    }
]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d4820dc845b8> in <module>()
#       1
# ----> 2 faces = fetch_olivetti_faces(data_home=olivetti_home)
#       3 # Define a param grid
#       4 param_grid = [
#       5     {
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/olivetti_faces.py in fetch_olivetti_faces(data_home, shuffle, random_state, download_if_missing)
#      89         Description of the modified Olivetti Faces Dataset.
#      90     """
# ---> 91     data_home = get_data_home(data_home=data_home)
#      92     if not exists(data_home):
#      93         makedirs(data_home)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/base.py in get_data_home(data_home)
#      54     data_home = expanduser(data_home)
#      55     if not exists(data_home):
# ---> 56         makedirs(data_home)
#      57     return data_home
#      58
#
# /usr/lib/python3.6/os.py in makedirs(name, mode, exist_ok)
#     218             return
#     219     try:
# --> 220         mkdir(name, mode)
#     221     except OSError:
#     222         # Cannot rely on checking for EEXIST, since the operating system
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# Create a train grid search on SVM classifier
gs = GridSearchCV(estimator=SVC(), param_grid=param_grid,
                  scoring='accuracy', cv=10, n_jobs=multiprocessing.cpu_count())
gs.fit(faces.data, faces.target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8566cce70501> in <module>()
# ----> 1 gs = GridSearchCV(estimator=SVC(), param_grid=param_grid,
#       2                   scoring='accuracy', cv=10, n_jobs=multiprocessing.cpu_count())
#       3 gs.fit(faces.data, faces.target)
#
# NameError: name 'param_grid' is not defined

# %%
print(gs.best_estimator_)
print('Kernel SVM score: %.3f' % gs.best_score_)
